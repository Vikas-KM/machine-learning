# %% [markdown]
# ### Dealing with missing data in Pandas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dummy_df = pd.read_csv('./datasets/dummy_data.csv')
dummy_df.head()
# Out:
#    Sno     Name   Age  Height(cm)
# 0    1     John  25.0       160.0
# 1    2    Jimmy  26.0       163.0
# 2    3  Felicia  28.0       154.0
# 3    4   Sophia   NaN       143.0
# 4    5      Bob   NaN         NaN

# %%
dummy_df.describe()
# Out:
#             Sno        Age  Height(cm)
# count  9.000000   6.000000    7.000000
# mean   5.000000  28.166667  154.857143
# std    2.738613   2.316607    7.174691
# min    1.000000  25.000000  143.000000
# 25%    3.000000  26.500000  151.000000
# 50%    5.000000  28.500000  156.000000
# 75%    7.000000  29.750000  160.000000
# max    9.000000  31.000000  163.000000

# %%
dummy_df.isnull()
# Out:
#      Sno   Name    Age  Height(cm)
# 0  False  False  False       False
# 1  False  False  False       False
# 2  False  False  False       False
# 3  False  False   True       False
# 4  False  False   True        True
# 5  False  False  False       False
# 6  False  False  False       False
# 7  False  False  False        True
# 8  False  False   True       False

# %%
dummy_df.isna()
# Out:
#      Sno   Name    Age  Height(cm)
# 0  False  False  False       False
# 1  False  False  False       False
# 2  False  False  False       False
# 3  False  False   True       False
# 4  False  False   True        True
# 5  False  False  False       False
# 6  False  False  False       False
# 7  False  False  False        True
# 8  False  False   True       False

# %%
dummy_df.notna()
# Out:
#     Sno  Name    Age  Height(cm)
# 0  True  True   True        True
# 1  True  True   True        True
# 2  True  True   True        True
# 3  True  True  False        True
# 4  True  True  False       False
# 5  True  True   True        True
# 6  True  True   True        True
# 7  True  True   True       False
# 8  True  True  False        True

# %%
dummy_df.isna().sum()
# Out:
# Sno           0
# Name          0
# Age           3
# Height(cm)    2
# dtype: int64

# %%
dummy_df.dtypes
# Out:
# Sno             int64
# Name           object
# Age           float64
# Height(cm)    float64
# dtype: object

# %%
str_dummy_df = pd.read_csv('./datasets/dummy_str_data.csv')
str_dummy_df.head()
# Out:
#    Sno      Device_name             Device_description Single-Use
# 0    1         Synringe        Used to inject medicine       True
# 1    2       Ventilator   Used to help patients breath      False
# 2    3  Surgical Gloves                            NaN       True
# 3    4     Stethescopes                            NaN        NaN
# 4    5  Vials container                            NaN        NaN

# %%
str_dummy_df.dtypes
# Out:
# Sno                    int64
# Device_name           object
# Device_description    object
# Single-Use            object
# dtype: object

# %%
str_dummy_df.describe()
# Out:
#             Sno
# count  5.000000
# mean   3.000000
# std    1.581139
# min    1.000000
# 25%    2.000000
# 50%    3.000000
# 75%    4.000000
# max    5.000000

# %%
str_dummy_df.isnull()
# Out:
#      Sno  Device_name  Device_description  Single-Use
# 0  False        False               False       False
# 1  False        False               False       False
# 2  False        False                True       False
# 3  False        False                True        True
# 4  False        False                True        True

# %%
str_dummy_df.isna().sum()
# Out:
# Sno                   0
# Device_name           0
# Device_description    3
# Single-Use            2
# dtype: int64

# %%
str_dummy_df
# Out:
#    Sno      Device_name             Device_description Single-Use
# 0    1         Synringe        Used to inject medicine       True
# 1    2       Ventilator   Used to help patients breath      False
# 2    3  Surgical Gloves                            NaN       True
# 3    4     Stethescopes                            NaN        NaN
# 4    5  Vials container                            NaN        NaN

# %%
time_df = pd.read_csv('./datasets/dummy_time.csv')
time_df.head()
# Out:
#    Unnamed: 0  Sno     Name   Age  Height(cm)    birthday
# 0           0    1     John  25.0       160.0  1994-01-01
# 1           1    2    Jimmy  26.0       163.0         NaN
# 2           2    3  Felicia  28.0       154.0  1995-01-01
# 3           3    4   Sophia   NaN       143.0         NaN
# 4           4    5      Bob   NaN         NaN  1994-01-01

# %%
time_df.dtypes
# Out:
# Unnamed: 0      int64
# Sno             int64
# Name           object
# Age           float64
# Height(cm)    float64
# birthday       object
# dtype: object

# %%
time_df.describe()
# Out:
#        Unnamed: 0       Sno        Age  Height(cm)
# count    9.000000  9.000000   6.000000    7.000000
# mean     4.000000  5.000000  28.166667  154.857143
# std      2.738613  2.738613   2.316607    7.174691
# min      0.000000  1.000000  25.000000  143.000000
# 25%      2.000000  3.000000  26.500000  151.000000
# 50%      4.000000  5.000000  28.500000  156.000000
# 75%      6.000000  7.000000  29.750000  160.000000
# max      8.000000  9.000000  31.000000  163.000000

# %%
time_df.isna().sum()
# Out:
# Unnamed: 0    0
# Sno           0
# Name          0
# Age           3
# Height(cm)    2
# birthday      3
# dtype: int64

# %%
time_df['birthday'] = pd.to_datetime(time_df['birthday'])
time_df.head()
# Out:
#    Unnamed: 0  Sno     Name   Age  Height(cm)   birthday
# 0           0    1     John  25.0       160.0 1994-01-01
# 1           1    2    Jimmy  26.0       163.0        NaT
# 2           2    3  Felicia  28.0       154.0 1995-01-01
# 3           3    4   Sophia   NaN       143.0        NaT
# 4           4    5      Bob   NaN         NaN 1994-01-01

# %% [markdown]
# missing values in datetime are replaced as `NaT`

# %%
time_df.dtypes
# Out:
# Unnamed: 0             int64
# Sno                    int64
# Name                  object
# Age                  float64
# Height(cm)           float64
# birthday      datetime64[ns]
# dtype: object
