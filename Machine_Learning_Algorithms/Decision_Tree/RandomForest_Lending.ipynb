# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %% [markdown]
# ## Read the loan data

# %%
loans = pd.read_csv('./loan_data.csv')

# %%
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
loans.describe()
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
loans['credit.policy'].value_counts()
# Out:
# 1    7710
# 0    1868
# Name: credit.policy, dtype: int64

# %% [markdown]
# ## FICO histogram based on credit policy

# %%
loans[loans['credit.policy']==1]['fico'].hist(bins=30, label='Credit Policy is 1', alpha=0.6)
loans[loans['credit.policy']==0]['fico'].hist(bins=30, label='Credit Policy is 0', alpha=0.6)
plt.legend()

# %% [markdown]
# ## Not Fully Paid histogram

# %%
loans['not.fully.paid'].value_counts()
# Out:
# 0    8045
# 1    1533
# Name: not.fully.paid, dtype: int64

# %%
loans[loans['not.fully.paid']==1]['fico'].hist(bins=35, label='Not Fully Paid is 1', alpha=0.6)
loans[loans['not.fully.paid']==0]['fico'].hist(bins=35, label='Not Fully Paid is 0', alpha=0.6)
plt.legend()

# %% [markdown]
# ## Count plot of loans purpose

# %%
plt.figure(figsize=(12,7))
sns.countplot(x='purpose', hue='not.fully.paid', data=loans)

# %% [markdown]
# ## Trend between FICO score and interest rate

# %%
sns.jointplot(x='fico', y='int.rate', data=loans)

# %% [markdown]
# ## lmplots to see trend between not.fully.paid and credit policy

# %%
sns.lmplot(y='int.rate', x='fico', data=loans, hue='credit.policy', col='not.fully.paid')

# %% [markdown]
# ## setting up the data

# %%
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
loans['purpose'].value_counts()
# Out:
# debt_consolidation    3957
# all_other             2331
# credit_card           1262
# home_improvement       629
# small_business         619
# major_purchase         437
# educational            343
# Name: purpose, dtype: int64

# %% [markdown]
# ### purpose is a categorical data

# %%
final_data = pd.get_dummies(loans, columns=['purpose'], drop_first=True)

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   credit.policy               9578 non-null   int64
#  1   int.rate                    9578 non-null   float64
#  2   installment                 9578 non-null   float64
#  3   log.annual.inc              9578 non-null   float64
#  4   dti                         9578 non-null   float64
#  5   fico                        9578 non-null   int64
#  6   days.with.cr.line           9578 non-null   float64
#  7   revol.bal                   9578 non-null   int64
#  8   revol.util                  9578 non-null   float64
#  9   inq.last.6mths              9578 non-null   int64
#  10  delinq.2yrs                 9578 non-null   int64
#  11  pub.rec                     9578 non-null   int64
#  12  not.fully.paid              9578 non-null   int64
# ...

# %%
final_data.head()
# Out:
#    credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 0              1    0.1189       829.10       11.350407  19.48   737
# 1              1    0.1071       228.22       11.082143  14.29   707
# 2              1    0.1357       366.86       10.373491  11.63   682
# 3              1    0.1008       162.34       11.350407   8.10   712
# 4              1    0.1426       102.92       11.299732  14.97   667
#
#    days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# 0        5639.958333      28854        52.1               0            0
# 1        2760.000000      33623        76.7               0            0
# 2        4710.000000       3511        25.6               1            0
# 3        2699.958333      33667        73.2               1            0
# 4        4066.000000       4740        39.5               0            1
#
#    pub.rec  not.fully.paid  purpose_credit_card  purpose_debt_consolidation  \
# ...

# %% [markdown]
# ## Train_Test_Split

# %%
from sklearn.model_selection import train_test_split

# %%
X = final_data.drop('not.fully.paid', axis=1)
y = final_data['not.fully.paid']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3)

# %% [markdown]
# ## Decision Tree Model

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ## Predictions and evaluations

# %%
y_pred = dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[2011  411]
#  [ 359   93]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84      2422
#            1       0.18      0.21      0.19       452
#
#     accuracy                           0.73      2874
#    macro avg       0.52      0.52      0.52      2874
# weighted avg       0.74      0.73      0.74      2874

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=100)

# %%
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
rfc_pred = rfc.predict(X_test)

# %%
print(confusion_matrix(y_test, rfc_pred))
# Out:
# [[2402   20]
#  [ 442   10]]

# %%
print(classification_report(y_test, rfc_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.99      0.91      2422
#            1       0.33      0.02      0.04       452
#
#     accuracy                           0.84      2874
#    macro avg       0.59      0.51      0.48      2874
# weighted avg       0.76      0.84      0.78      2874
