# %%
import numpy as np
import pandas as pd

# %%
# %matplotlib inline

# %%
df1 = pd.read_csv('./datasets/df1.csv')
df1.head()
# Out:
#    Unnamed: 0         A         B         C         D
# 0  2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 1  2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2  2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 3  2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 4  2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1 = pd.read_csv('./datasets/df1.csv', index_col=0)
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('./datasets/df2.csv')
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
# rceating the histogram from the column of the df
df1['A'].hist()

# %%
import seaborn as sns

# %%
df1['A'].hist()

# %%
df1['A'].plot(kind='hist')

# %%
df1['A'].plot(kind='hist', bins=20)

# %%
sns.set_style('darkgrid')

# %%
df2['a'].plot(kind='hist')

# %%
df2.plot.area()

# %%
df1.plot(kind='hist')

# %%
df2.plot.bar()

# %%
df2
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %%
df2.plot.bar(stacked=True)

# %%
df1['A'].plot.hist(bins=30)

# %%
df1
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ...              ...       ...       ...       ...
# 2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 4 columns]

# %%
df1.plot.line()

# %%
df1.plot.scatter(x='A',y='B')

# %%
df1.plot.scatter(x='A',y='B', c=df1['C'])

# %%
df1.plot.scatter(x='A',y='B', c=df1['C'], cmap='coolwarm')

# %%
df1.plot.scatter(x='A',y='B', s=df1['C']*100)
# Out:
# C:\Users\Vikas\anaconda3\lib\site-packages\matplotlib\collections.py:857: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df1.plot.box()

# %%
df2['a'].plot.kde()

# %%
df2.plot.kde()

# %%
df3 = pd.read_csv('./datasets/df3.csv')
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
# s is size
df3.plot.scatter(x='a',y='b', c='r', s=50)

# %%
df3['a'].plot.hist()

# %%
df3.plot.box()

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
df3.plot.box()

# %%
df3[['a','b']].plot.box()

# %%
df3.plot.kde()

# %%
df3['a'].plot.kde(lw=3,ls='--')

# %%
df3.plot.area()

# %%
df3[0:30].plot.area()

# %% [markdown]
# ### Inserting legend outside the figure

# %%
df3[0:30].plot.area()
plt.legend(loc='center left', bbox_to_anchor=(1.0,0.5))
