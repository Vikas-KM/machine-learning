# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Dataset from kaggle
# * https://www.kaggle.com/mathijs/weather-data-in-new-york-city-2016

# %%
nyc_weather = pd.read_csv('./datasets/weather_data_nyc_centralpark_2016.csv')
nyc_weather.head(5)
# Out:
#        date  maximum temperature  minimum temperature  average temperature  \
# 0  1-1-2016                   42                   34                 38.0
# 1  2-1-2016                   40                   32                 36.0
# 2  3-1-2016                   45                   35                 40.0
# 3  4-1-2016                   36                   14                 25.0
# 4  5-1-2016                   29                   11                 20.0
#
#   precipitation snow fall snow depth
# 0          0.00       0.0          0
# 1          0.00       0.0          0
# 2          0.00       0.0          0
# 3          0.00       0.0          0
# 4          0.00       0.0          0

# %%
plt.plot(nyc_weather['maximum temperature'])
plt.show()

# %%
plt.plot(nyc_weather['minimum temperature'])
plt.show()

# %%
### Finding the max temperate
nyc_weather['maximum temperature'].max()
# Out:
# 96

# %%
nyc_weather['minimum temperature'].min()
# Out:
# -1

# %%
x = nyc_weather['date'][:10]
y = nyc_weather['maximum temperature'][:10]
plt.figure(figsize=(10,6))
plt.subplot(1,1,1)
plt.plot(x,y)
plt.show()

# %%
nyc_weather.columns
# Out:
# Index(['date', 'maximum temperature', 'minimum temperature',
#        'average temperature', 'precipitation', 'snow fall', 'snow depth'],
#       dtype='object')

# %%
nyc_weather.dtypes
# Out:
# date                    object
# maximum temperature      int64
# minimum temperature      int64
# average temperature    float64
# precipitation           object
# snow fall               object
# snow depth              object
# dtype: object

# %%
nyc_weather.isna().sum()
# Out:
# date                   0
# maximum temperature    0
# minimum temperature    0
# average temperature    0
# precipitation          0
# snow fall              0
# snow depth             0
# dtype: int64

# %%
nyc_weather.describe()
# Out:
#        maximum temperature  minimum temperature  average temperature
# count           366.000000           366.000000           366.000000
# mean             64.625683            49.806011            57.215847
# std              18.041787            16.570747            17.124760
# min              15.000000            -1.000000             7.000000
# 25%              50.000000            37.250000            44.000000
# 50%              64.500000            48.000000            55.750000
# 75%              81.000000            65.000000            73.500000
# max              96.000000            81.000000            88.500000

# %%
nyc_weather['maximum temperature'].max()
# Out:
# 96

# %%
nyc_weather[nyc_weather['maximum temperature']== nyc_weather['maximum temperature'].max()]
# Out:
#           date  maximum temperature  minimum temperature  average temperature  \
# 204  23-7-2016                   96                   80                 88.0
# 225  13-8-2016                   96                   81                 88.5
#
#     precipitation snow fall snow depth
# 204             0         0          0
# 225             0         0          0

# %%
nyc_weather['snow fall'].unique()
# Out:
# array(['0.0', 'T', '0.4', '0.2', '27.3', '2.5', '0.1', '1.4', '0.5', '0',
#        '2.8'], dtype=object)

# %%
# if you dont need index, pass index=False
nyc_weather.to_excel('./datasets/weather_data.xlsx', sheet_name='weather_data', index=False)

# %%
weather_data_xls = pd.read_excel('./datasets/weather_data.xlsx')
weather_data_xls.head(5)
# Out:
#        date  maximum temperature  minimum temperature  average temperature  \
# 0  1-1-2016                   42                   34                 38.0
# 1  2-1-2016                   40                   32                 36.0
# 2  3-1-2016                   45                   35                 40.0
# 3  4-1-2016                   36                   14                 25.0
# 4  5-1-2016                   29                   11                 20.0
#
#   precipitation snow fall snow depth
# 0          0.00       0.0          0
# 1          0.00       0.0          0
# 2          0.00       0.0          0
# 3          0.00       0.0          0
# 4          0.00       0.0          0
